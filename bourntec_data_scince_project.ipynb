# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinmayadas2003/Data-Science-Resources/blob/master/bourntec_data_scince_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import openai
import re
import pandas as pd

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI
    response = openai.Completion.create(
        engine='text-davinci-003',
        prompt=f"What is the business description for NAICS {naics_number}?",
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response if available
    if response.choices and response.choices[0].text:
        description = response.choices[0].text.strip()
    else:
        description = "Empty"

    return description

# Example NAICS numbers
naics_numbers = ['541613', '541611', '541512', '111110']  # Including an invalid NAICS number for testing

# Create a list to store individual dataframes
dfs = []

# Iterate through NAICS numbers
for naics_number in naics_numbers:
    description = get_business_description(naics_number)
    df = pd.DataFrame({'NAICS Number': [naics_number], 'Business Description': [description]})
    dfs.append(df)

# Concatenate all dataframes into a single dataframe
results = pd.concat(dfs, ignore_index=True)

# Print the results
print(results)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-10-7cf4cce8b0eb> in <cell line: 34>()
#      33 # Iterate through NAICS numbers
#      34 for naics_number in naics_numbers:
# ---> 35     description = get_business_description(naics_number)
#      36     df = pd.DataFrame({'NAICS Number': [naics_number], 'Business Description': [description]})
#      37     dfs.append(df)
#
# <ipython-input-10-7cf4cce8b0eb> in get_business_description(naics_number)
#       8 def get_business_description(naics_number):
#       9     # Retrieve business description from OpenAI
# ---> 10     response = openai.Completion.create(
#      11         engine='text-davinci-003',
#      12         prompt=f"What is the business description for NAICS {naics_number}?",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
# ...

# %%
import os
import openai

openai.api_key = "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"

response = openai.Completion.create(
  model="text-davinci-003",
  prompt="",
  temperature=1,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-14-e0f7cd08ec85> in <cell line: 6>()
#       4 openai.api_key = "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"
#       5
# ----> 6 response = openai.Completion.create(
#       7   model="text-davinci-003",
#       8   prompt="",
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     151         )
#     152
# ...

# %%
import openai
import re
import pandas as pd

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo
    response = openai.Completion.create(
        engine='gpt-3.5-turbo',
        prompt=f"What is the business description for NAICS {naics_number}?",
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].text.strip()

    return description

# Example NAICS numbers
naics_numbers = ['541613', '541611', '541512', '111110']  # Including an invalid NAICS number for testing

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Iterate through NAICS numbers
for naics_number in naics_numbers:
    try:
        description = get_business_description(naics_number)
    except:
        description = "Empty"

    results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# <ipython-input-19-cc6f05dfc385>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)
# <ipython-input-19-cc6f05dfc385>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)
#   NAICS Number Business Description
# 0       541613                Empty
# 1       541611                Empty
# 2       541512                Empty
# 3       111110                Empty
# <ipython-input-19-cc6f05dfc385>:37: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
import openai
import re
import pandas as pd
import concurrent.futures

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo
    response = openai.Completion.create(
        engine='gpt-3.5-turbo',
        prompt=f"What is the business description for NAICS {naics_number}?",
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].text.strip()

    return description

# Example NAICS numbers
naics_numbers = ['541613', '541611', '541512', '111110']  # Including an invalid NAICS number for testing

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Define the number of workers for parallel processing
num_workers = 5

# Create a ThreadPoolExecutor for parallel processing
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each NAICS number
    future_to_naics = {executor.submit(get_business_description, naics_number): naics_number for naics_number in naics_numbers}

    # Process completed tasks
    for future in concurrent.futures.as_completed(future_to_naics):
        naics_number = future_to_naics[future]
        try:
            description = future.result()
        except Exception as e:
            print(f"An error occurred during API call for NAICS {naics_number}: {e}")
            description = "Empty"

        results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# An error occurred during API call for NAICS 541512: You exceeded your current quota, please check your plan and billing details.
# <ipython-input-21-8cc4185e5773>:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)
# An error occurred during API call for NAICS 541613: You exceeded your current quota, please check your plan and billing details.
# An error occurred during API call for NAICS 541611: You exceeded your current quota, please check your plan and billing details.
# An error occurred during API call for NAICS 111110: You exceeded your current quota, please check your plan and billing details.
#   NAICS Number Business Description
# 0       541512                Empty
# 1       541613                Empty
# 2       541611                Empty
# ...

# %%
import openai
import re
import pandas as pd
import time

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo
    response = openai.Completion.create(
        engine='gpt-3.5-turbo',
        prompt=f"What is the business description for NAICS {naics_number}?",
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].text.strip()

    return description

# Generate a larger dataset of NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10100)]  # Example range of NAICS numbers

# Simple for loop approach
start_time = time.time()

results_simple = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

for naics_number in naics_numbers:
    description = get_business_description(naics_number)
    results_simple = results_simple.append({'NAICS Number': naics_number, 'Business Description': description},
                                           ignore_index=True)

end_time = time.time()
elapsed_time_simple = end_time - start_time

# Parallel processing approach
start_time = time.time()

results_parallel = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

num_workers = 10

with concurrent.futures.ThreadPoolExecutor() as executor:
    future_to_naics = {executor.submit(get_business_description, naics_number): naics_number for naics_number in
                       naics_numbers}

    for future in concurrent.futures.as_completed(future_to_naics):
        naics_number = future_to_naics[future]
        try:
            description = future.result()
        except Exception as e:
            print(f"An error occurred during API call for NAICS {naics_number}: {e}")
            description = "Empty"

        results_parallel = results_parallel.append({'NAICS Number': naics_number, 'Business Description': description},
                                                   ignore_index=True)

end_time = time.time()
elapsed_time_parallel = end_time - start_time

# Print the elapsed times
print(f"Elapsed time (Simple for loop): {elapsed_time_simple} seconds")
print(f"Elapsed time (Parallel processing): {elapsed_time_parallel} seconds")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-22-6cff05e27af8> in <cell line: 33>()
#      32
#      33 for naics_number in naics_numbers:
# ---> 34     description = get_business_description(naics_number)
#      35     results_simple = results_simple.append({'NAICS Number': naics_number, 'Business Description': description},
#      36                                            ignore_index=True)
#
# <ipython-input-22-6cff05e27af8> in get_business_description(naics_number)
#       9 def get_business_description(naics_number):
#      10     # Retrieve business description from OpenAI using GPT-3.5 Turbo
# ---> 11     response = openai.Completion.create(
#      12         engine='gpt-3.5-turbo',
#      13         prompt=f"What is the business description for NAICS {naics_number}?",
#
# ...

# %%
import openai
import re
import pandas as pd
import time
import concurrent.futures

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo
    response = openai.Completion.create(
        engine='gpt-3.5-turbo',
        prompt=f"What is the business description for NAICS {naics_number}?",
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].text.strip()

    return description

# Generate a larger dataset of NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10100)]  # Example range of NAICS numbers

# Simple for loop approach
start_time = time.time()

results_simple = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

for naics_number in naics_numbers:
    description = get_business_description(naics_number)
    results_simple = results_simple.append({'NAICS Number': naics_number, 'Business Description': description},
                                           ignore_index=True)

end_time = time.time()
elapsed_time_simple = end_time - start_time

# Parallel processing approach
start_time = time.time()

results_parallel = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

num_workers = 10

with concurrent.futures.ThreadPoolExecutor() as executor:
    future_to_naics = {executor.submit(get_business_description, naics_number): naics_number for naics_number in
                       naics_numbers}

    for future in concurrent.futures.as_completed(future_to_naics):
        naics_number = future_to_naics[future]
        try:
            description = future.result()
        except Exception as e:
            print(f"An error occurred during API call for NAICS {naics_number}: {e}")
            description = "Empty"

        results_parallel = results_parallel.append({'NAICS Number': naics_number, 'Business Description': description},
                                                   ignore_index=True)

end_time = time.time()
elapsed_time_parallel = end_time - start_time

# Print the elapsed times
print(f"Elapsed time (Simple for loop): {elapsed_time_simple} seconds")
print(f"Elapsed time (Parallel processing): {elapsed_time_parallel} seconds")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-24-7776804f06dc> in <cell line: 34>()
#      33
#      34 for naics_number in naics_numbers:
# ---> 35     description = get_business_description(naics_number)
#      36     results_simple = results_simple.append({'NAICS Number': naics_number, 'Business Description': description},
#      37                                            ignore_index=True)
#
# <ipython-input-24-7776804f06dc> in get_business_description(naics_number)
#      10 def get_business_description(naics_number):
#      11     # Retrieve business description from OpenAI using GPT-3.5 Turbo
# ---> 12     response = openai.Completion.create(
#      13         engine='gpt-3.5-turbo',
#      14         prompt=f"What is the business description for NAICS {naics_number}?",
#
# ...

# %%
import openai
import re
import pandas as pd

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
    response = openai.Completion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"What is the business description for NAICS {naics_number}?"}
        ],
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].message.content.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10200)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Iterate through NAICS numbers
for naics_number in naics_numbers:
    try:
        description = get_business_description(naics_number)
    except Exception as e:
        print(f"An error occurred during API call for NAICS {naics_number}: {e}")
        description = "Empty"

    results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# An error occurred during API call for NAICS 10000: Unrecognized request argument supplied: messages
# An error occurred during API call for NAICS 10001: Rate limit reached for default-gpt-3.5-turbo in organization org-1mqxv4VpRvipaq9JQ9Sixtjr on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# An error occurred during API call for NAICS 10002: Rate limit reached for default-gpt-3.5-turbo in organization org-1mqxv4VpRvipaq9JQ9Sixtjr on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# ...

# %%
import openai
import re
import pandas as pd
import concurrent.futures

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
    response = openai.Completion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"What is the business description for NAICS {naics_number}?"}
        ],
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].message.content.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10200)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Define the number of workers for parallel processing
num_workers = 10

# Create a ThreadPoolExecutor for parallel processing
with concurrent.futures.ThreadPoolExecutor(max_workers=num_workers) as executor:
    # Submit tasks for each NAICS number
    future_to_naics = {executor.submit(get_business_description, naics_number): naics_number for naics_number in naics_numbers}

    # Process completed tasks
    for future in concurrent.futures.as_completed(future_to_naics):
        naics_number = future_to_naics[future]
        try:
            description = future.result()
        except Exception as e:
            print(f"An error occurred during API call for NAICS {naics_number}: {e}")
            description = "Empty"

        results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# An error occurred during API call for NAICS 10003: Rate limit reached for default-gpt-3.5-turbo in organization org-1mqxv4VpRvipaq9JQ9Sixtjr on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# An error occurred during API call for NAICS 10007: Rate limit reached for default-gpt-3.5-turbo in organization org-1mqxv4VpRvipaq9JQ9Sixtjr on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.
# ...

# %%
import openai
import re
import pandas as pd
from numba import jit

# Set up OpenAI API credentials
openai.api_key = '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'

@jit(nopython=True)  # Apply JIT compilation to improve performance
def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
    response = openai.Completion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"What is the business description for NAICS {naics_number}?"}
        ],
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].message.content.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10200)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Iterate through NAICS numbers
for naics_number in naics_numbers:
    try:
        description = get_business_description(naics_number)
    except Exception as e:
        print(f"An error occurred during API call for NAICS {naics_number}: {e}")
        description = "Empty"

    results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# An error occurred during API call for NAICS 10000: Failed in nopython mode pipeline (step: nopython frontend)
# Unknown attribute 'Completion' of type Module(<module 'openai' from '/usr/local/lib/python3.10/dist-packages/openai/__init__.py'>)
#
# File "<ipython-input-29-cc95199a706d>", line 12:
# def get_business_description(naics_number):
#     <source elided>
#     # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
#     response = openai.Completion.create(
#     ^
#
# During: typing of get attribute at <ipython-input-29-cc95199a706d> (12)
#
# File "<ipython-input-29-cc95199a706d>", line 12:
# def get_business_description(naics_number):
#     <source elided>
#     # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
#     response = openai.Completion.create(
#     ^
#
# An error occurred during API call for NAICS 10001: Failed in nopython mode pipeline (step: nopython frontend)
# ...

# %%
import openai
import re
import pandas as pd

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo model
    prompt = f"What is the business description for NAICS {naics_number}?"
    response = openai.Completion.create(
        model='gpt-3.5-turbo',
        prompt=prompt,
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].text.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10200)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Iterate through NAICS numbers and retrieve descriptions
for naics_number in naics_numbers:
    description = get_business_description(naics_number)
    results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-3-7abfff9d7ec0> in <cell line: 32>()
#      31 # Iterate through NAICS numbers and retrieve descriptions
#      32 for naics_number in naics_numbers:
# ---> 33     description = get_business_description(naics_number)
#      34     results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)
#      35
#
# <ipython-input-3-7abfff9d7ec0> in get_business_description(naics_number)
#       9     # Retrieve business description from OpenAI using GPT-3.5 Turbo model
#      10     prompt = f"What is the business description for NAICS {naics_number}?"
# ---> 11     response = openai.Completion.create(
#      12         model='gpt-3.5-turbo',
#      13         prompt=prompt,
#
# ...

# %% [markdown]
# ###master code

# %%
import openai
import re
import pandas as pd

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
    response = openai.ChatCompletion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"What is the business description for NAICS {naics_number}?"}
        ],
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].message.content.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10002)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Iterate through NAICS numbers and retrieve descriptions
for naics_number in naics_numbers:
    description = get_business_description(naics_number)
    results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# Print the results
print(results)
# Out:
# <ipython-input-4-462bb9655542>:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({'NAICS Number': naics_number, 'Business Description': description}, ignore_index=True)

# %% [markdown]
# ## fsater result

# %%
import openai
import re
import pandas as pd
import concurrent.futures

# Set up OpenAI API credentials
openai.api_key = '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'

def get_business_description(naics_number):
    # Retrieve business description from OpenAI using GPT-3.5 Turbo chat model
    response = openai.ChatCompletion.create(
        model='gpt-3.5-turbo',
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"What is the business description for NAICS {naics_number}?"}
        ],
        max_tokens=1000,
        n=1,
        stop=None,
        temperature=0.5,
    )

    # Extract the description from the OpenAI response
    description = response.choices[0].message.content.strip()

    return description

# Example NAICS numbers
naics_numbers = [str(i) for i in range(10000, 10002)]  # Example range of NAICS numbers

# Create a dataframe to store the results
results = pd.DataFrame(columns=['NAICS Number', 'Business Description'])

# Define a helper function to retrieve descriptions in parallel
def retrieve_description(naics_number):
    description = get_business_description(naics_number)
    return {'NAICS Number': naics_number, 'Business Description': description}

# Use ThreadPoolExecutor for concurrent processing
with concurrent.futures.ThreadPoolExecutor() as executor:
    # Submit tasks for each NAICS number
    futures = [executor.submit(retrieve_description, naics_number) for naics_number in naics_numbers]

    # Process completed tasks and append results to the DataFrame
    for future in concurrent.futures.as_completed(futures):
        result = future.result()
        results = results.append(result, ignore_index=True)

# Print the results
print(results)
# Out:
# <ipython-input-5-628ca42ff60d>:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(result, ignore_index=True)
#   NAICS Number                               Business Description
# 0        10000  NAICS 10000 refers to the sector of Agricultur...
# 1        10001  The North American Industry Classification Sys...
# <ipython-input-5-628ca42ff60d>:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(result, ignore_index=True)
